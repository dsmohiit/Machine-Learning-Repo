# %% [markdown]
# <a href="https://colab.research.google.com/github/dsmohiit/Machine-Learning-Repo/blob/main/Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/placement.csv")

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
# Ploting the scatter plot.
# CGPA and Package have a sort of linear relationship.
plt.scatter(df["cgpa"], df["package"], alpha= 0.5)
plt.xlabel("CGPA")
plt.ylabel("PACKAGE")

plt.title("CGPA vs PACKAGE")
plt.show()

# %%
x = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state= 2)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_ctc = lr.predict(x_test)
predicted_ctc = pd.DataFrame({
    "predicted_ctc": predicted_ctc
})

predicted_ctc
# Out:
#     predicted_ctc
# 0        3.891116
# 1        3.093245
# 2        2.384646
# 3        2.574349
# 4        1.653729
# 5        1.776478
# 6        2.072193
# 7        2.931439
# 8        3.762787
# 9        2.937018
# 10       4.091979
# 11       3.511709
# 12       2.970495
# 13       2.401384
# 14       3.188097
# 15       3.467073
# 16       1.943864
# 17       3.243892
# 18       2.976075
# 19       3.416857
# 20       2.557611
# 21       3.165778
# 22       2.858905
# 23       3.121142
# 24       3.684674
# 25       2.870064
# 26       3.494970
# 27       3.344323
# 28       3.919014
# 29       1.960602
# 30       3.651197
# 31       3.210415
# 32       3.740469
# 33       2.786371
# 34       2.780792
# 35       3.271789
# 36       3.528447
# 37       2.613406
# 38       2.658042
# 39       2.713837

# %%
plt.scatter(df["cgpa"], df["package"], alpha= 0.5)
plt.plot(x_train, lr.predict(x_train), color= "red", label= "Best Fit Line")
plt.xlabel("CGPA")
plt.ylabel("PACKAGE")

plt.title("CGPA vs PACKAGE")
plt.legend()
plt.show()

# %%
# Value of slope (m).
m = lr.coef_
m
# Out:
# array([0.55795197])

# %%
# Value of intercept (b).
b = lr.intercept_
b
# Out:
# -0.8961119222429144

# %%
class MyLinearRegression():

  def __init__(self):
    self.m = None
    self.b = None

  def fit(self, x_train, y_train):
    x_train = np.array(x_train).flatten()
    y_train = np.array(y_train).flatten()

    x_train_mean = x_train.mean()
    y_train_mean = y_train.mean()


    num = np.sum((x_train - x_train_mean) * (y_train - y_train_mean))
    den = np.sum((x_train - x_train_mean) ** 2)

    self.m = num / den
    self.b = y_train_mean - (self.m * x_train_mean)

  def predict(self, x_test):
    return (self.m * x_test) + self.b

  def coef_(self):
    return self.m

  def intercept_(self):
    return self.b

# %%
mlr = MyLinearRegression()

# %%
mlr.fit(x_train, y_train)

# %%
mlr.coef_()
# Out:
# 0.557951973425072

# %%
mlr.predict(x_test)
# Out:
#          cgpa
# 112  3.891116
# 29   3.093245
# 182  2.384646
# 199  2.574349
# 193  1.653729
# 85   1.776478
# 10   2.072193
# 54   2.931439
# 115  3.762787
# 35   2.937018
# 12   4.091979
# 92   3.511709
# 13   2.970495
# 126  2.401384
# 174  3.188097
# 2    3.467073
# 44   1.943864
# 3    3.243892
# 113  2.976075
# 14   3.416857
# 23   2.557611
# 25   3.165778
# 6    2.858905
# 134  3.121142
# 165  3.684674
# 173  2.870064
# 45   3.494970
# 65   3.344323
# 48   3.919014
# 122  1.960602
# 178  3.651197
# 64   3.210415
# 9    3.740469
# 57   2.786371
# 78   2.780792
# 71   3.271789
# 128  3.528447
# 176  2.613406
# 131  2.658042
# 53   2.713837
